# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Full Reduced Individual Model Comparison.csv')

# %%
data.head()
# Out:
#   Model Number  Number of Hidden Layers  Full Accuracy  Reduced Accuracy  \
# 0      Model 1                        3         0.8427            0.8418
# 1      Model 2                        4         0.8486            0.8454
# 2      Model 3                        2         0.8483            0.8464
# 3      Model 4                        5         0.8452            0.8432
# 4      Model 5                        5         0.8455            0.8449
#
#    Full AUC  Reduced AUC  Full Loss  Reduced Loss  Full Precision  \
# 0    0.9302       0.9268     0.3461        0.3486          0.8886
# 1    0.9303       0.9277     0.3439        0.3425          0.8361
# 2    0.9308       0.9280     0.3349        0.3421          0.8481
# 3    0.9305       0.9271     0.3413        0.3492          0.8753
# 4    0.9305       0.9279     0.3382        0.3420          0.8627
#
#    Reduced Precision  Full Recall  Reduced Recall
# 0             0.8271       0.7721          0.8150
# 1             0.8379       0.8549          0.8446
# 2             0.8496       0.8366          0.8300
# 3             0.8311       0.7935          0.8489
# 4             0.8405       0.8288          0.8391

# %%
# Generate box plots using the DataFrame
metrics_pairs = [
    ("Full Accuracy", "Reduced Accuracy"),
    ("Full AUC", "Reduced AUC"),
    ("Full Loss", "Reduced Loss"),
    ("Full Precision", "Reduced Precision"),
    ("Full Recall", "Reduced Recall")
]

for full_metric, reduced_metric in metrics_pairs:
    plt.figure(figsize=(6, 4))
    plt.boxplot(
        [data[full_metric], data[reduced_metric]],
        labels=[full_metric, reduced_metric],
        patch_artist=True
    )
    plt.title(f'Boxplot for {full_metric} and {reduced_metric}')
    plt.ylabel('Values')
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.show()
